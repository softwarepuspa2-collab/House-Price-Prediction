# %% [markdown]
# #Importing Required Libraries

# %% [markdown]
# **Reading dataset**

# %%
#importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("/content/train.csv")
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# # Checking Missing values

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %% [markdown]
# ## Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# # Feature and Target Selection

# %%
X=df.drop('SalePrice',axis=1)
y=df['SalePrice']

# %%
print("Shape of x:",X.shape)
print("Shape of y:",y.shape)
# Out:
# Shape of x: (1460, 80)
# Shape of y: (1460,)

# %% [markdown]
# # Train Test Split

# %%
# Train Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=30)

# %%
print("X_train shape:",X_train.shape)
print("X_test shape:",X_test.shape)
# Out:
# X_train shape: (1022, 80)
# X_test shape: (438, 80)

# %%
print("y_train shape:",y_train.shape)
print("y_test shape:",y_test.shape)
# Out:
# y_train shape: (1022,)
# y_test shape: (438,)

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
import pandas as pd

X_train = pd.get_dummies(X_train)
X_test  = pd.get_dummies(X_test)

# %%
X_train, X_test = X_train.align(X_test, join='left', axis=1, fill_value=0)

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit(X_train)
X_train=sc.transform(X_train)
X_test=sc.transform(X_test)

# %%
import numpy as np

X_train = np.nan_to_num(X_train)
X_test  = np.nan_to_num(X_test)

# %% [markdown]
# # Model Training using Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Model Evaluation(before prediction)

# %%
lr.score(X_test,y_test)
# Out:
# 0.8909779522299693

# %% [markdown]
# # Model Prediction

# %%
lr.predict([X_test[0,:]])
# Out:
# array([170217.84066293])

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
y_pred=lr.predict(X_test)
X_pred=lr.predict(X_train)
y_pred
X_pred
# Out:
# array([354791.09266333, 106587.62214216, 181028.93961614, ...,
#        113685.22775971, 210384.89358206, 217045.81004028])

# %%
print("MAE Value:",mean_absolute_error(y_test,y_pred))
print("MSE Value:",mean_squared_error(y_test,y_pred))
# Out:
# MAE Value: 18371.02547633733
# MSE Value: 802729769.6400601

# %%
lr_rmse= np.sqrt(mean_squared_error(y_test,y_pred))
lr_rmse
# Out:
# np.float64(28332.48611823643)

# %% [markdown]
# **Accuracy**

# %%
lr_r2 = r2_score(y_test,y_pred)
lr_r2
# Out:
# 0.8909779522299693

# %% [markdown]
# #Traning model using Random Forest

# %%
print("Training Score:",lr.score(X_train,y_train))
print("Testing Score:",lr.score(X_test,y_test))
# Out:
# Training Score: 0.9332340075705624
# Testing Score: 0.8909779522299693

# %%
from sklearn.ensemble import RandomForestRegressor
rf_model = RandomForestRegressor()
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# **Accuracy**

# %%
rf_rmse = np.sqrt(mean_squared_error(y_test, rf_model.predict(X_test)))
rf_r2   = r2_score(y_test, rf_model.predict(X_test))
rf_rmse
rf_r2
# Out:
# 0.8541215821140389

# %%
print("Linear Regression RMSE:", lr_rmse)
print("Linear Regression R2:", lr_r2)

print("Random Forest RMSE:", rf_rmse)
print("Random Forest R2:", rf_r2)
# Out:
# Linear Regression RMSE: 28332.48611823643
# Linear Regression R2: 0.8909779522299693
# Random Forest RMSE: 32773.51627177672
# Random Forest R2: 0.8541215821140389

# %% [markdown]
# # Installing Gradio

# %%
# !pip install gradio

# %% [markdown]
# #Importing Required Libraries

# %% [markdown]
# **gradio for UIUX**

# %%
import numpy as np
import pandas as pd
import gradio as gr
from sklearn.linear_model import LinearRegression

# Load dataset
df = pd.read_csv("/content/train.csv")

# Select important features
features = ['OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', 'FullBath']
df = df[features + ['SalePrice']]

# Drop missing values
df = df.dropna()

# Split features and target
X = df[features]
y = df['SalePrice']

# Train model
model = LinearRegression()
model.fit(X, y)

# Prediction function
def predict_price(OverallQual, GrLivArea, GarageCars, TotalBsmtSF, FullBath):
    input_data = np.array([[OverallQual, GrLivArea, GarageCars, TotalBsmtSF, FullBath]])
    prediction = model.predict(input_data)
    return f"🏠 Predicted House Price: ₹ {round(prediction[0], 2)}"

# Create UI
demo = gr.Interface(
    fn=predict_price,
    inputs=[
        gr.Slider(1, 10, label="Overall Quality (1-10)"),
        gr.Number(label="Above Ground Living Area (sq ft)"),
        gr.Slider(0, 4, label="Garage Capacity (cars)"),
        gr.Number(label="Total Basement Area (sq ft)"),
        gr.Slider(0, 4, label="Number of Full Bathrooms")
    ],
    outputs="text",
    title="🏠 House Price Prediction System",
    description="Enter house details to estimate the selling price."
)

demo.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://88a6b93035e538594c.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://88a6b93035e538594c.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import numpy as np
import pandas as pd
import gradio as gr
from sklearn.linear_model import LinearRegression

# Load Dataset


df = pd.read_csv("/content/train.csv")

features = ['OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', 'FullBath']
df = df[features + ['SalePrice']]
df = df.dropna()

X = df[features]
y = df['SalePrice']

model = LinearRegression()
model.fit(X, y)

# Prediction Function

def predict_price(OverallQual, GrLivArea, GarageCars, TotalBsmtSF, FullBath):
    input_data = np.array([[OverallQual, GrLivArea, GarageCars, TotalBsmtSF, FullBath]])
    prediction = model.predict(input_data)
    return f"🏠 Predicted House Price: ₹ {round(prediction[0], 2)}"


# ===============================
# WORKING CSS FOR GRADIO
# ===============================
css = """
.gradio-container {
    background: url(https://lifetinyhouse.com/wp-content/uploads/2024/01/Tiny-House-Design-With-Swimming-Pool12-1024x576.png)
                no-repeat center center fixed;
    background-size: cover;
}

/* Blur overlay */
.gradio-container::before {
    content: "";
    position: fixed;
    inset: 0;
    background: rgba(0,0,0,0.55);
    backdrop-filter: blur(8px);
    z-index: -1;
}

/* Floating white card */
#main-box {
    background: rgba(255,255,255,0.95);
    border-radius: 22px;
    padding: 35px;
    margin: 40px auto;
    max-width: 760px;
    box-shadow: 0 25px 60px rgba(0,0,0,0.45);
}

/* Title */
.title-text {
    text-align: center;
    color: white;
    font-size: 42px;
    font-weight: bold;
    margin-top: 25px;
}

/* Button style */
button {
  background: linear-gradient(135deg, #ff7e5f, #ff3f34) !important;
    color: white !important;
    border-radius: 14px !important;
    font-size: 18px !important;
    box-shadow: 0 8px 22px rgba(0,0,0,0.35);
}
"""

# UI

with gr.Blocks(css=css) as demo:

    gr.Markdown("<div class='title-text'>🏠 House Price Prediction System</div>")

    with gr.Column(elem_id="main-box"):

        OverallQual = gr.Slider(1, 10, label="Overall Quality (1-10)")
        GrLivArea = gr.Number(label="Above Ground Living Area (sq ft)")
        GarageCars = gr.Slider(0, 6, label="Garage Capacity (cars)")
        TotalBsmtSF = gr.Number(label="Total Basement Area (sq ft)")
        FullBath = gr.Slider(0, 4, label="Number of Full Bathrooms")

        btn = gr.Button("✨ Predict Price")

        output = gr.Textbox(label="Estimated Price")

        btn.click(
            predict_price,
            inputs=[OverallQual, GrLivArea, GarageCars, TotalBsmtSF, FullBath],
            outputs=output
        )

demo.launch()
# Out:
# /tmp/ipython-input-569/1411739240.py:80: DeprecationWarning: The 'css' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'css' to Blocks.launch() instead.
#   with gr.Blocks(css=css) as demo:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://49aac6c43c252bb9e0.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# ...
